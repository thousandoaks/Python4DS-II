# %% [markdown]
# # Healthcare Lab (Text Processing)

# %% [markdown]
# **Learning Objectives:**
#   * Practice time series operations
#
#   * Gain exposure to healthcare related DataSets

# %% [markdown]
# ## Context of the dataset
#
# ### 1. The dataset is consisted of records corresponding to medical events.
# ### 2. Each medical event is uniquely identified by `MedicalClaim`.
# ### 3. A given medical event might involve several medical procedures.
# ### 4. Each medical procedure is uniquely identified by `ClaimItem`
# ### 5. A given medical procedure is characterized by `PrincipalDiagnosisDesc`,`PrincipalDiagnosis`,`RevenueCodeDesc`, `RevenueCode`, `TypeFlag` and `TotalExpenses`
#
# ### 6. Each medical procedure involves: `MemberName`,`MemberID`,`County`,`HospitalName`, `HospitalType`, `StartDate`,`EndDate`

# %% [markdown]
# ## 1. Library Import

# %%
import pandas as pd
import warnings
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
warnings.simplefilter('ignore')

# %% [markdown]
# ## 2. Data loading and DataFrame creation

# %%
HealthCareDataSet=pd.read_csv("https://github.com/thousandoaks/Python4DS-I/raw/main/datasets/HealthcareDataset_PublicRelease.csv",sep=',',parse_dates=['StartDate','EndDate','BirthDate'])

# %%
HealthCareDataSet.head(10)
# Out:
#        Id MemberName  MemberID    County      MedicalClaim  ClaimItem  \
# 0  634363   e659f3f4  6a380a28  6f943458  c1e3436737c77899         18
# 1  634364   e659f3f4  6a380a28  6f943458  c1e3436737c77899         21
# 2  634387   e659f3f4  6a380a28  6f943458  c1e3436737c77899         10
# 3  634388   e659f3f4  6a380a28  6f943458  c1e3436737c77899         20
# 4  634389   e659f3f4  6a380a28  6f943458  c1e3436737c77899         19
# 5  634390   e659f3f4  6a380a28  6f943458  c1e3436737c77899          2
# 6  634391   e659f3f4  6a380a28  6f943458  c1e3436737c77899          6
# 7  634392   e659f3f4  6a380a28  6f943458  c1e3436737c77899         12
# 8  634393   e659f3f4  6a380a28  6f943458  c1e3436737c77899         15
# 9  634394   e659f3f4  6a380a28  6f943458  c1e3436737c77899         17
#
#   HospitalName HospitalType  StartDate    EndDate PrincipalDiagnosisDesc  \
# 0     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# 1     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# 2     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# 3     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# 4     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# 5     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# 6     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# 7     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# 8     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# 9     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
#
#   PrincipalDiagnosis                                    RevenueCodeDesc  \
# 0             R10.13  DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...
# 1             R10.13  DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...
# 2             R10.13       LABORATORY - CLINICAL DIAGNOSTIC: HEMATOLOGY
# 3             R10.13  DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...
# 4             R10.13  DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...
# 5             R10.13        LABORATORY - CLINICAL DIAGNOSTIC: CHEMISTRY
# 6             R10.13        LABORATORY - CLINICAL DIAGNOSTIC: CHEMISTRY
# 7             R10.13                RADIOLOGY - DIAGNOSTIC: CHEST X-RAY
# 8             R10.13                                     EMERGENCY ROOM
# 9             R10.13                                     EMERGENCY ROOM
#
#    RevenueCode TypeFlag  BirthDate  TotalExpenses PrincipalDiagnosisSplit  \
# 0        636.0       ER 1967-05-13         15.148               [R10, 13]
# 1        636.0       ER 1967-05-13          3.073               [R10, 13]
# 2        305.0       ER 1967-05-13        123.900               [R10, 13]
# 3        636.0       ER 1967-05-13          7.511               [R10, 13]
# 4        636.0       ER 1967-05-13          8.631               [R10, 13]
# 5        301.0       ER 1967-05-13        263.200               [R10, 13]
# 6        301.0       ER 1967-05-13         44.100               [R10, 13]
# 7        324.0       ER 1967-05-13        364.000               [R10, 13]
# 8        450.0       ER 1967-05-13        789.600               [R10, 13]
# 9        450.0       ER 1967-05-13        478.100               [R10, 13]
#
#   PrincipalDiagnosisDescExtract RevenueCodeDescExtract
# 0                           NaN                    NaN
# 1                           NaN                    NaN
# 2                           NaN                    NaN
# 3                           NaN                    NaN
# 4                           NaN                    NaN
# 5                           NaN                    NaN
# 6                           NaN                    NaN
# 7                           NaN                    NaN
# 8                           NaN                    NaN
# 9                           NaN                    NaN

# %%
HealthCareDataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52563 entries, 0 to 52562
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Id                      52563 non-null  int64
#  1   MemberName              52563 non-null  object
#  2   MemberID                52563 non-null  object
#  3   County                  52563 non-null  object
#  4   MedicalClaim            52563 non-null  object
#  5   ClaimItem               52563 non-null  int64
#  6   HospitalName            52563 non-null  object
#  7   HospitalType            52563 non-null  object
#  8   StartDate               52563 non-null  datetime64[ns]
#  9   EndDate                 52563 non-null  datetime64[ns]
#  10  PrincipalDiagnosisDesc  52563 non-null  object
#  11  PrincipalDiagnosis      52563 non-null  object
#  12  RevenueCodeDesc         52561 non-null  object
#  13  RevenueCode             52563 non-null  float64
#  14  TypeFlag                52563 non-null  object
#  15  BirthDate               52563 non-null  datetime64[ns]
#  16  TotalExpenses           52563 non-null  float64
# dtypes: datetime64[ns](3), float64(2), int64(2), object(10)
# memory usage: 6.8+ MB

# %% [markdown]
# ## 3. Let's find all records containing the word Sprain in the PrincipalDiagnosisDesc
# ### Tip: Use chatGPT to find the right regex expression: https://chatgpt.com/share/95a71cec-b278-45c4-b4c8-865ff085c80a

# %%
regexPattern=r'\b[sS]prain\b'

# %%
HealthCareDataSet[HealthCareDataSet['PrincipalDiagnosisDesc'].str.contains(regexPattern, regex=True)]
# Out:
#            Id MemberName  MemberID    County      MedicalClaim  ClaimItem  \
# 918    635736   eec5c2b9  558f84ad  89e38653  090c146fa3932f54          2
# 919    635737   eec5c2b9  558f84ad  89e38653  090c146fa3932f54          3
# 920    635738   eec5c2b9  558f84ad  89e38653  090c146fa3932f54          1
# 2145   638036   588584f1  b9f9e2d3  02af982d  ca62615a0bdccc7b          2
# 2158   638059   588584f1  b9f9e2d3  02af982d  ca62615a0bdccc7b          1
# ...       ...        ...       ...       ...               ...        ...
# 49084  733413   25b294ad  b41fcbc8  02af982d  5b88bbc6c91d1dfe          1
# 49085  733425   25b294ad  b41fcbc8  02af982d  5b88bbc6c91d1dfe          2
# 49495  734523   eec5c2b9  558f84ad  89e38653  3dfc8d295cff09f7          1
# 49496  734524   eec5c2b9  558f84ad  89e38653  3dfc8d295cff09f7          2
# 49497  734525   eec5c2b9  558f84ad  89e38653  3dfc8d295cff09f7          3
#
#       HospitalName HospitalType  StartDate    EndDate  \
# 918       b592f5ae     HOSPITAL 2020-01-20 2020-01-20
# 919       b592f5ae     HOSPITAL 2020-01-20 2020-01-20
# 920       b592f5ae     HOSPITAL 2020-01-20 2020-01-20
# 2145      88b42459     HOSPITAL 2020-01-01 2020-01-01
# 2158      88b42459     HOSPITAL 2020-01-01 2020-01-01
# ...            ...          ...        ...        ...
# 49084     4d103af0     HOSPITAL 2020-12-24 2020-12-24
# 49085     4d103af0     HOSPITAL 2020-12-24 2020-12-24
# 49495     b592f5ae     HOSPITAL 2020-12-06 2020-12-06
# 49496     b592f5ae     HOSPITAL 2020-12-06 2020-12-06
# 49497     b592f5ae     HOSPITAL 2020-12-06 2020-12-06
#
#           PrincipalDiagnosisDesc PrincipalDiagnosis         RevenueCodeDesc  \
# 918    Sprain of unspecified lig           S93.401A  RADIOLOGY - DIAGNOSTIC
# 919    Sprain of unspecified lig           S93.401A          EMERGENCY ROOM
# 920    Sprain of unspecified lig           S93.401A                PHARMACY
# 2145   Unspecified sprain of rig           S63.501A  RADIOLOGY - DIAGNOSTIC
# 2158   Unspecified sprain of rig           S63.501A                PHARMACY
# ...                          ...                ...                     ...
# 49084  Sprain of unspecified lig           S93.401A  RADIOLOGY - DIAGNOSTIC
# 49085  Sprain of unspecified lig           S93.401A          EMERGENCY ROOM
# 49495  Sprain of unspecified lig           S93.402A                PHARMACY
# 49496  Sprain of unspecified lig           S93.402A  RADIOLOGY - DIAGNOSTIC
# 49497  Sprain of unspecified lig           S93.402A          EMERGENCY ROOM
#
#        RevenueCode TypeFlag  BirthDate  TotalExpenses
# 918          320.0       ER 1964-08-29       1059.156
# 919          450.0       ER 1964-08-29       2098.096
# 920          250.0       ER 1964-08-29          2.975
# 2145         320.0       ER 1961-03-05        347.200
# 2158         250.0       ER 1961-03-05          0.364
# ...            ...      ...        ...            ...
# 49084        320.0       ER 1939-08-02        618.800
# 49085        450.0       ER 1939-08-02       2774.842
# 49495        250.0       ER 1964-08-29          2.044
# 49496        320.0       ER 1964-08-29       1059.156
# 49497        450.0       ER 1964-08-29       2108.589
#
# [124 rows x 17 columns]

# %% [markdown]
# ## 3. Let's split the field PrincipalDiagnosis into two.
# ### Tip: use chatGPT to find the right regex: https://chatgpt.com/share/045d60d0-6a4f-4288-b73d-501d29b619f6

# %%
regexPattern=r'\.'

# %%
HealthCareDataSet['PrincipalDiagnosisSplit']=HealthCareDataSet['PrincipalDiagnosis'].str.split(regexPattern)
HealthCareDataSet['PrincipalDiagnosisSplit']
# Out:
# 0          [R10, 13]
# 1          [R10, 13]
# 2          [R10, 13]
# 3          [R10, 13]
# 4          [R10, 13]
#             ...
# 52558    [S06, 6X0A]
# 52559       [D50, 0]
# 52560       [D50, 0]
# 52561       [D50, 0]
# 52562       [D50, 0]
# Name: PrincipalDiagnosisSplit, Length: 52563, dtype: object

# %% [markdown]
# ## 4. Given the column `RevenueCodeDesc`, let's extract all words following the text: "LABORATORY - CLINICAL DIAGNOSTIC"
#
#
#
# ### Tip: Use chatGPT to find the right regex expression: https://chatgpt.com/share/16f39595-847a-4844-8d82-a021ee02af9c

# %%
regexPattern=pattern = r'LABORATORY - CLINICAL DIAGNOSTIC:\s*(.*)'

# %%
HealthCareDataSet['RevenueCodeDescExtract']=HealthCareDataSet['RevenueCodeDesc'].str.extract(regexPattern)
HealthCareDataSet['RevenueCodeDescExtract']
# Out:
# 0               NaN
# 1               NaN
# 2        HEMATOLOGY
# 3               NaN
# 4               NaN
#             ...
# 52558           NaN
# 52559    HEMATOLOGY
# 52560           NaN
# 52561           NaN
# 52562     CHEMISTRY
# Name: RevenueCodeDescExtract, Length: 52563, dtype: object

# %%
HealthCareDataSet.groupby(['RevenueCodeDescExtract']).count()
# Out:
#                              Id  MemberName  MemberID  County  MedicalClaim  \
# RevenueCodeDescExtract
# BACTERIOLOGY/MICROBIOLOGY  1831        1831      1831    1831          1831
# CHEMISTRY                  5857        5857      5857    5857          5857
# HEMATOLOGY                 4037        4037      4037    4037          4037
# IMMUNOLOGY                  929         929       929     929           929
# OTHER LABORATORY             91          91        91      91            91
# UROLOGY                    1353        1353      1353    1353          1353
#
#                            ClaimItem  HospitalName  HospitalType  StartDate  \
# RevenueCodeDescExtract
# BACTERIOLOGY/MICROBIOLOGY       1831          1831          1831       1831
# CHEMISTRY                       5857          5857          5857       5857
# HEMATOLOGY                      4037          4037          4037       4037
# IMMUNOLOGY                       929           929           929        929
# OTHER LABORATORY                  91            91            91         91
# UROLOGY                         1353          1353          1353       1353
#
#                            EndDate  PrincipalDiagnosisDesc  \
# RevenueCodeDescExtract
# BACTERIOLOGY/MICROBIOLOGY     1831                    1831
# CHEMISTRY                     5857                    5857
# HEMATOLOGY                    4037                    4037
# IMMUNOLOGY                     929                     929
# OTHER LABORATORY                91                      91
# UROLOGY                       1353                    1353
#
#                            PrincipalDiagnosis  RevenueCodeDesc  RevenueCode  \
# RevenueCodeDescExtract
# BACTERIOLOGY/MICROBIOLOGY                1831             1831         1831
# CHEMISTRY                                5857             5857         5857
# HEMATOLOGY                               4037             4037         4037
# IMMUNOLOGY                                929              929          929
# OTHER LABORATORY                           91               91           91
# UROLOGY                                  1353             1353         1353
#
#                            TypeFlag  BirthDate  TotalExpenses  \
# RevenueCodeDescExtract
# BACTERIOLOGY/MICROBIOLOGY      1831       1831           1831
# CHEMISTRY                      5857       5857           5857
# HEMATOLOGY                     4037       4037           4037
# IMMUNOLOGY                      929        929            929
# OTHER LABORATORY                 91         91             91
# UROLOGY                        1353       1353           1353
#
#                            PrincipalDiagnosisSplit  \
# RevenueCodeDescExtract
# BACTERIOLOGY/MICROBIOLOGY                     1831
# CHEMISTRY                                     5857
# HEMATOLOGY                                    4037
# IMMUNOLOGY                                     929
# OTHER LABORATORY                                91
# UROLOGY                                       1353
#
#                            PrincipalDiagnosisDescExtract
# RevenueCodeDescExtract
# BACTERIOLOGY/MICROBIOLOGY                              0
# CHEMISTRY                                              0
# HEMATOLOGY                                             0
# IMMUNOLOGY                                             0
# OTHER LABORATORY                                       0
# UROLOGY                                                0
