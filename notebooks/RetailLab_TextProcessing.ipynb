# %% [markdown]
# # Retail Lab (Time Series)

# %% [markdown]
# **Learning Objectives:**
#   * Apply text processing techniques
#   * Gain exposure to retail related DataSets

# %% [markdown]
# ## Context of the datasets
#
# ### 1. There are three datasets: `articles.csv.zip`, `customers.csv.zip` and `transactions2020.csv.zip`
#
# #### 2. The Articles dataset contains information over products available.
# #### 3. The Customers dataset contains information over registered customers.
# #### 4. The Transactions dataset contains purchases of articles made by customers.

# %% [markdown]
# ## 1. Library Import

# %%
import pandas as pd
import warnings
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
warnings.simplefilter('ignore')

# %% [markdown]
# ## 2. Data loading and DataFrame creation

# %%
Articles=pd.read_csv("https://github.com/thousandoaks/Python4DS-I/raw/main/datasets/articles.csv.zip")

# %%
Articles.head(3)
# Out:
#    article_id  product_code      prod_name  product_type_no product_type_name  \
# 0   108775015        108775      Strap top              253          Vest top
# 1   108775044        108775      Strap top              253          Vest top
# 2   108775051        108775  Strap top (1)              253          Vest top
#
#    product_group_name  graphical_appearance_no graphical_appearance_name  \
# 0  Garment Upper body                  1010016                     Solid
# 1  Garment Upper body                  1010016                     Solid
# 2  Garment Upper body                  1010017                    Stripe
#
#    colour_group_code colour_group_name  ...  department_name index_code  \
# 0                  9             Black  ...     Jersey Basic          A
# 1                 10             White  ...     Jersey Basic          A
# 2                 11         Off White  ...     Jersey Basic          A
#
#    index_name index_group_no  index_group_name section_no  \
# 0  Ladieswear              1        Ladieswear         16
# 1  Ladieswear              1        Ladieswear         16
# 2  Ladieswear              1        Ladieswear         16
#
#              section_name garment_group_no  garment_group_name  \
# 0  Womens Everyday Basics             1002        Jersey Basic
# 1  Womens Everyday Basics             1002        Jersey Basic
# 2  Womens Everyday Basics             1002        Jersey Basic
#
#                                detail_desc
# 0  Jersey top with narrow shoulder straps.
# 1  Jersey top with narrow shoulder straps.
# 2  Jersey top with narrow shoulder straps.
#
# [3 rows x 25 columns]

# %%
Articles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105542 entries, 0 to 105541
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   article_id                    105542 non-null  int64
#  1   product_code                  105542 non-null  int64
#  2   prod_name                     105542 non-null  object
#  3   product_type_no               105542 non-null  int64
#  4   product_type_name             105542 non-null  object
#  5   product_group_name            105542 non-null  object
#  6   graphical_appearance_no       105542 non-null  int64
#  7   graphical_appearance_name     105542 non-null  object
#  8   colour_group_code             105542 non-null  int64
#  9   colour_group_name             105542 non-null  object
#  10  perceived_colour_value_id     105542 non-null  int64
#  11  perceived_colour_value_name   105542 non-null  object
#  12  perceived_colour_master_id    105542 non-null  int64
#  13  perceived_colour_master_name  105542 non-null  object
#  14  department_no                 105542 non-null  int64
#  15  department_name               105542 non-null  object
#  16  index_code                    105542 non-null  object
#  17  index_name                    105542 non-null  object
#  18  index_group_no                105542 non-null  int64
#  19  index_group_name              105542 non-null  object
#  20  section_no                    105542 non-null  int64
#  21  section_name                  105542 non-null  object
#  22  garment_group_no              105542 non-null  int64
#  23  garment_group_name            105542 non-null  object
#  24  detail_desc                   105126 non-null  object
# dtypes: int64(11), object(14)
# memory usage: 20.1+ MB

# %%
Customers=pd.read_csv("https://github.com/thousandoaks/Python4DS-I/raw/main/datasets/customers.csv.zip")

# %%
Customers.sample(3)
# Out:
#                                                customer_id  FN  Active  \
# 389573   48d1f8dbb09254515fc28c65f9d9e638890a27dd91a6b2... NaN     NaN
# 445147   53372e5a495238af8b823172cf0b0496f7e0f1324bf2a9... NaN     NaN
# 1303907  f35058bb737bbcec400c6f6f92000eb676ca80738f8fa3... NaN     NaN
#
#         club_member_status fashion_news_frequency   age  \
# 389573              ACTIVE                   NONE  20.0
# 445147              ACTIVE                   NONE  46.0
# 1303907             ACTIVE                   NONE  29.0
#
#                                                postal_code
# 389573   77877b59d3ea31f6b92e0265470f7c14cc4b9500d452ee...
# 445147   da0bbaaed411a796e0f3fe9d83c799c4e7a081dbca5f26...
# 1303907  8e58f188f877bf922956381974378c1c9084d0a851e54b...

# %%
Customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1371980 entries, 0 to 1371979
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   customer_id             1371980 non-null  object
#  1   FN                      476930 non-null   float64
#  2   Active                  464404 non-null   float64
#  3   club_member_status      1365918 non-null  object
#  4   fashion_news_frequency  1355969 non-null  object
#  5   age                     1356119 non-null  float64
#  6   postal_code             1371980 non-null  object
# dtypes: float64(3), object(4)
# memory usage: 73.3+ MB

# %%
Transactions=pd.read_csv("https://github.com/thousandoaks/Python4DS-I/raw/main/datasets/transactions2020.csv.zip")

# %%
Transactions.sample(3)
# Out:
#               t_dat                                        customer_id  \
# 1367834  2020-06-25  3dd2c55ad8eeebb7565517b3dcbd6663ffc4fb56117af3...
# 4229318  2020-08-28  c7e3984a6751ada06f9630fa47e6d7ff7a469a4d0fdd85...
# 1563079  2020-06-27  afcf094f564b93cdba75438414ba0ea737a12cc9f6b082...
#
#          article_id     price  sales_channel_id
# 1367834   876327001  0.010153                 1
# 4229318   918292001  0.042356                 2
# 1563079   878510002  0.015237                 2

# %%
Transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5151470 entries, 0 to 5151469
# Data columns (total 5 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   t_dat             object
#  1   customer_id       object
#  2   article_id        int64
#  3   price             float64
#  4   sales_channel_id  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 196.5+ MB

# %% [markdown]
# ## 3. Merging DataFrames

# %% [markdown]
# #### 3.1. Transactions-Articles

# %%
Transactions.head(3)
# Out:
#         t_dat                                        customer_id  article_id  \
# 0  2020-06-01  00075ef36696a7b4ed8c83e22a4bf7ea7c90ee110991ec...   844198001
# 1  2020-06-01  000b31552d3785c79833262bbeefa484cbc43d7b612b3c...   777016001
# 2  2020-06-01  002d8d26c9414c981c012c6f5e4b2de7ffd3bc568c4574...   820507001
#
#       price  sales_channel_id
# 0  0.016932                 2
# 1  0.030492                 1
# 2  0.010153                 2

# %%
Articles.head(3)
# Out:
#    article_id  product_code      prod_name  product_type_no product_type_name  \
# 0   108775015        108775      Strap top              253          Vest top
# 1   108775044        108775      Strap top              253          Vest top
# 2   108775051        108775  Strap top (1)              253          Vest top
#
#    product_group_name  graphical_appearance_no graphical_appearance_name  \
# 0  Garment Upper body                  1010016                     Solid
# 1  Garment Upper body                  1010016                     Solid
# 2  Garment Upper body                  1010017                    Stripe
#
#    colour_group_code colour_group_name  ...  department_name index_code  \
# 0                  9             Black  ...     Jersey Basic          A
# 1                 10             White  ...     Jersey Basic          A
# 2                 11         Off White  ...     Jersey Basic          A
#
#    index_name index_group_no  index_group_name section_no  \
# 0  Ladieswear              1        Ladieswear         16
# 1  Ladieswear              1        Ladieswear         16
# 2  Ladieswear              1        Ladieswear         16
#
#              section_name garment_group_no  garment_group_name  \
# 0  Womens Everyday Basics             1002        Jersey Basic
# 1  Womens Everyday Basics             1002        Jersey Basic
# 2  Womens Everyday Basics             1002        Jersey Basic
#
#                                detail_desc
# 0  Jersey top with narrow shoulder straps.
# 1  Jersey top with narrow shoulder straps.
# 2  Jersey top with narrow shoulder straps.
#
# [3 rows x 25 columns]

# %%
## we merge both DataFrames using the common key: article_id. We store the result in a new DataFrame
TransactionsAndArticles=pd.merge(Transactions, Articles, how='left',on='article_id')

# %% [markdown]
# #### 3.2. Transactions-Articles-Customers

# %%
TransactionsAndArticles.head(3)
# Out:
#         t_dat                                        customer_id  article_id  \
# 0  2020-06-01  00075ef36696a7b4ed8c83e22a4bf7ea7c90ee110991ec...   844198001
# 1  2020-06-01  000b31552d3785c79833262bbeefa484cbc43d7b612b3c...   777016001
# 2  2020-06-01  002d8d26c9414c981c012c6f5e4b2de7ffd3bc568c4574...   820507001
#
#       price  sales_channel_id  product_code                  prod_name  \
# 0  0.016932                 2        844198             Saturn trs (J)
# 1  0.030492                 1        777016                Cisco skirt
# 2  0.010153                 2        820507  Charlotte Hipster Primula
#
#    product_type_no product_type_name  product_group_name  ...  \
# 0              296     Pyjama bottom           Nightwear  ...
# 1              275             Skirt  Garment Lower body  ...
# 2              286  Underwear bottom           Underwear  ...
#
#        department_name index_code        index_name index_group_no  \
# 0            Nightwear          B  Lingeries/Tights              1
# 1     Trousers & Skirt          A        Ladieswear              1
# 2  Expressive Lingerie          B  Lingeries/Tights              1
#
#    index_group_name section_no                    section_name  \
# 0        Ladieswear         62  Womens Nightwear, Socks & Tigh
# 1        Ladieswear         18                    Womens Trend
# 2        Ladieswear         61                 Womens Lingerie
#
#   garment_group_no  garment_group_name  \
# 0             1017   Under-, Nightwear
# 1             1009            Trousers
# 2             1017   Under-, Nightwear
#
#                                          detail_desc
# 0  Pyjama bottoms in sweatshirt fabric with wide ...
# 1  Calf-length skirt in softly draping, patterned...
# 2  Hipster briefs in lace with a mid waist, lined...
#
# [3 rows x 29 columns]

# %%
Customers.head(3)
# Out:
#                                          customer_id  FN  Active  \
# 0  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3... NaN     NaN
# 1  0000423b00ade91418cceaf3b26c6af3dd342b51fd051e... NaN     NaN
# 2  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca... NaN     NaN
#
#   club_member_status fashion_news_frequency   age  \
# 0             ACTIVE                   NONE  49.0
# 1             ACTIVE                   NONE  25.0
# 2             ACTIVE                   NONE  24.0
#
#                                          postal_code
# 0  52043ee2162cf5aa7ee79974281641c6f11a68d276429a...
# 1  2973abc54daa8a5f8ccfe9362140c63247c5eee03f1d93...
# 2  64f17e6a330a85798e4998f62d0930d14db8db1c054af6...

# %%
## we merge both DataFrames using the common key: customer_id. We store the result in a new DataFrame
TransactionsAndArticlesAndCustomers=pd.merge(TransactionsAndArticles, Customers, how='left',on='customer_id')

# %%
TransactionsAndArticlesAndCustomers.head(3).T
# Out:
# t_dat                                                                2020-06-01  \
# t_dat                                                       2020-06-01 00:00:00
# customer_id                   00075ef36696a7b4ed8c83e22a4bf7ea7c90ee110991ec...
# article_id                                                            844198001
# price                                                                  0.016932
# sales_channel_id                                                              2
# product_code                                                             844198
# prod_name                                                        Saturn trs (J)
# product_type_no                                                             296
# product_type_name                                                 Pyjama bottom
# product_group_name                                                    Nightwear
# graphical_appearance_no                                                 1010016
# graphical_appearance_name                                                 Solid
# colour_group_code                                                             7
# colour_group_name                                                          Grey
# perceived_colour_value_id                                                     1
# perceived_colour_value_name                                         Dusty Light
# perceived_colour_master_id                                                   12
# perceived_colour_master_name                                               Grey
# department_no                                                              3709
# department_name                                                       Nightwear
# index_code                                                                    B
# index_name                                                     Lingeries/Tights
# index_group_no                                                                1
# index_group_name                                                     Ladieswear
# section_no                                                                   62
# section_name                                     Womens Nightwear, Socks & Tigh
# garment_group_no                                                           1017
# garment_group_name                                            Under-, Nightwear
# detail_desc                   Pyjama bottoms in sweatshirt fabric with wide ...
# FN                                                                          NaN
# Active                                                                      NaN
# club_member_status                                                       ACTIVE
# fashion_news_frequency                                                     NONE
# age                                                                        40.0
# postal_code                   0c0e15f8fa88a1d4aa6ca8a0b4a8289ca1affbaebdea22...
#
# t_dat                                                                2020-06-01  \
# t_dat                                                       2020-06-01 00:00:00
# customer_id                   000b31552d3785c79833262bbeefa484cbc43d7b612b3c...
# article_id                                                            777016001
# price                                                                  0.030492
# sales_channel_id                                                              1
# product_code                                                             777016
# prod_name                                                           Cisco skirt
# product_type_no                                                             275
# product_type_name                                                         Skirt
# product_group_name                                           Garment Lower body
# graphical_appearance_no                                                 1010001
# graphical_appearance_name                                      All over pattern
# colour_group_code                                                            73
# colour_group_name                                                     Dark Blue
# perceived_colour_value_id                                                     7
# perceived_colour_value_name                                              Medium
# perceived_colour_master_id                                                    2
# perceived_colour_master_name                                               Blue
# department_no                                                              1948
# department_name                                                Trousers & Skirt
# index_code                                                                    A
# index_name                                                           Ladieswear
# index_group_no                                                                1
# index_group_name                                                     Ladieswear
# section_no                                                                   18
# section_name                                                       Womens Trend
# garment_group_no                                                           1009
# garment_group_name                                                     Trousers
# detail_desc                   Calf-length skirt in softly draping, patterned...
# FN                                                                          1.0
# Active                                                                      1.0
# club_member_status                                                       ACTIVE
# fashion_news_frequency                                                Regularly
# age                                                                        59.0
# postal_code                   2c29ae653a9282cce4151bd87643c907644e09541abc28...
#
# t_dat                                                                2020-06-01
# t_dat                                                       2020-06-01 00:00:00
# customer_id                   002d8d26c9414c981c012c6f5e4b2de7ffd3bc568c4574...
# article_id                                                            820507001
# price                                                                  0.010153
# sales_channel_id                                                              2
# product_code                                                             820507
# prod_name                                             Charlotte Hipster Primula
# product_type_no                                                             286
# product_type_name                                              Underwear bottom
# product_group_name                                                    Underwear
# graphical_appearance_no                                                 1010016
# graphical_appearance_name                                                 Solid
# colour_group_code                                                             9
# colour_group_name                                                         Black
# perceived_colour_value_id                                                     4
# perceived_colour_value_name                                                Dark
# perceived_colour_master_id                                                    5
# perceived_colour_master_name                                              Black
# department_no                                                              1338
# department_name                                             Expressive Lingerie
# index_code                                                                    B
# index_name                                                     Lingeries/Tights
# index_group_no                                                                1
# index_group_name                                                     Ladieswear
# section_no                                                                   61
# section_name                                                    Womens Lingerie
# garment_group_no                                                           1017
# garment_group_name                                            Under-, Nightwear
# detail_desc                   Hipster briefs in lace with a mid waist, lined...
# FN                                                                          NaN
# Active                                                                      NaN
# club_member_status                                                       ACTIVE
# fashion_news_frequency                                                     NONE
# age                                                                        23.0
# postal_code                   8d4ceb946237cf52ce5c2a1a71d1221fde77627a52d661...

# %%
TransactionsAndArticlesAndCustomers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5151470 entries, 0 to 5151469
# Data columns (total 35 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   t_dat                         object
#  1   customer_id                   object
#  2   article_id                    int64
#  3   price                         float64
#  4   sales_channel_id              int64
#  5   product_code                  int64
#  6   prod_name                     object
#  7   product_type_no               int64
#  8   product_type_name             object
#  9   product_group_name            object
#  10  graphical_appearance_no       int64
#  11  graphical_appearance_name     object
#  12  colour_group_code             int64
#  13  colour_group_name             object
#  14  perceived_colour_value_id     int64
#  15  perceived_colour_value_name   object
#  16  perceived_colour_master_id    int64
#  17  perceived_colour_master_name  object
#  18  department_no                 int64
#  19  department_name               object
#  20  index_code                    object
#  21  index_name                    object
#  22  index_group_no                int64
#  23  index_group_name              object
#  24  section_no                    int64
#  25  section_name                  object
#  26  garment_group_no              int64
#  27  garment_group_name            object
#  28  detail_desc                   object
#  29  FN                            float64
#  30  Active                        float64
#  31  club_member_status            object
#  32  fashion_news_frequency        object
#  33  age                           float64
#  34  postal_code                   object
# dtypes: float64(4), int64(12), object(19)
# memory usage: 1.3+ GB

# %% [markdown]
# ## 4. Let's find all rows: (1) having the word "Trousers" in the column `garment_group_name` AND (2) having the word "Ladieswear" in the column `index_group_name`

# %%
TransactionsAndArticlesAndCustomers.groupby('index_group_name').count()
# Out:
#                     t_dat  customer_id  article_id    price  sales_channel_id  \
# index_group_name
# Baby/Children       88425        88425       88425    88425             88425
# Divided           1080962      1080962     1080962  1080962           1080962
# Ladieswear        3448578      3448578     3448578  3448578           3448578
# Menswear           303848       303848      303848   303848            303848
# Sport              229657       229657      229657   229657            229657
#
#                   product_code  prod_name  product_type_no  product_type_name  \
# index_group_name
# Baby/Children            88425      88425            88425              88425
# Divided                1080962    1080962          1080962            1080962
# Ladieswear             3448578    3448578          3448578            3448578
# Menswear                303848     303848           303848             303848
# Sport                   229657     229657           229657             229657
#
#                   product_group_name  ...  section_name  garment_group_no  \
# index_group_name                      ...
# Baby/Children                  88425  ...         88425             88425
# Divided                      1080962  ...       1080962           1080962
# Ladieswear                   3448578  ...       3448578           3448578
# Menswear                      303848  ...        303848            303848
# Sport                         229657  ...        229657            229657
#
#                   garment_group_name  detail_desc       FN   Active  \
# index_group_name
# Baby/Children                  88425        88407    41298    40628
# Divided                      1080962      1080956   490449   482639
# Ladieswear                   3448578      3444994  1554595  1532315
# Menswear                      303848       303846   139553   137577
# Sport                         229657       229653    94380    93073
#
#                   club_member_status  fashion_news_frequency      age  \
# index_group_name
# Baby/Children                  88104                   88045    87914
# Divided                      1079239                 1078667  1077290
# Ladieswear                   3444011                 3440093  3435019
# Menswear                      303522                  303134   302691
# Sport                         229389                  229023   228752
#
#                   postal_code
# index_group_name
# Baby/Children           88425
# Divided               1080962
# Ladieswear            3448578
# Menswear               303848
# Sport                  229657
#
# [5 rows x 34 columns]

# %%
TransactionsAndArticlesAndCustomers.groupby('garment_group_name').count()
# Out:
#                                 t_dat  customer_id  article_id   price  \
# garment_group_name
# Accessories                    254328       254328      254328  254328
# Blouses                        431929       431929      431929  431929
# Dressed                         72407        72407       72407   72407
# Dresses Ladies                 388742       388742      388742  388742
# Dresses/Skirts girls             4067         4067        4067    4067
# Jersey Basic                   586898       586898      586898  586898
# Jersey Fancy                   877520       877520      877520  877520
# Knitwear                       226507       226507      226507  226507
# Outdoor                         70172        70172       70172   70172
# Shirts                          33970        33970       33970   33970
# Shoes                          114846       114846      114846  114846
# Shorts                         166679       166679      166679  166679
# Skirts                         113024       113024      113024  113024
# Socks and Tights                97684        97684       97684   97684
# Special Offers                  24769        24769       24769   24769
# Swimwear                       515552       515552      515552  515552
# Trousers                       448022       448022      448022  448022
# Trousers Denim                 184581       184581      184581  184581
# Under-, Nightwear              494089       494089      494089  494089
# Unknown                         38662        38662       38662   38662
# Woven/Jersey/Knitted mix Baby    7022         7022        7022    7022
#
#                                sales_channel_id  product_code  prod_name  \
# garment_group_name
# Accessories                              254328        254328     254328
# Blouses                                  431929        431929     431929
# Dressed                                   72407         72407      72407
# Dresses Ladies                           388742        388742     388742
# Dresses/Skirts girls                       4067          4067       4067
# Jersey Basic                             586898        586898     586898
# Jersey Fancy                             877520        877520     877520
# Knitwear                                 226507        226507     226507
# Outdoor                                   70172         70172      70172
# Shirts                                    33970         33970      33970
# Shoes                                    114846        114846     114846
# Shorts                                   166679        166679     166679
# Skirts                                   113024        113024     113024
# Socks and Tights                          97684         97684      97684
# Special Offers                            24769         24769      24769
# Swimwear                                 515552        515552     515552
# Trousers                                 448022        448022     448022
# Trousers Denim                           184581        184581     184581
# Under-, Nightwear                        494089        494089     494089
# Unknown                                   38662         38662      38662
# Woven/Jersey/Knitted mix Baby              7022          7022       7022
#
#                                product_type_no  product_type_name  \
# garment_group_name
# Accessories                             254328             254328
# Blouses                                 431929             431929
# Dressed                                  72407              72407
# Dresses Ladies                          388742             388742
# Dresses/Skirts girls                      4067               4067
# Jersey Basic                            586898             586898
# Jersey Fancy                            877520             877520
# Knitwear                                226507             226507
# Outdoor                                  70172              70172
# Shirts                                   33970              33970
# Shoes                                   114846             114846
# Shorts                                  166679             166679
# Skirts                                  113024             113024
# Socks and Tights                         97684              97684
# Special Offers                           24769              24769
# Swimwear                                515552             515552
# Trousers                                448022             448022
# Trousers Denim                          184581             184581
# Under-, Nightwear                       494089             494089
# Unknown                                  38662              38662
# Woven/Jersey/Knitted mix Baby             7022               7022
#
#                                product_group_name  ...  section_no  \
# garment_group_name                                 ...
# Accessories                                254328  ...      254328
# Blouses                                    431929  ...      431929
# Dressed                                     72407  ...       72407
# Dresses Ladies                             388742  ...      388742
# Dresses/Skirts girls                         4067  ...        4067
# Jersey Basic                               586898  ...      586898
# Jersey Fancy                               877520  ...      877520
# Knitwear                                   226507  ...      226507
# Outdoor                                     70172  ...       70172
# Shirts                                      33970  ...       33970
# Shoes                                      114846  ...      114846
# Shorts                                     166679  ...      166679
# Skirts                                     113024  ...      113024
# Socks and Tights                            97684  ...       97684
# Special Offers                              24769  ...       24769
# Swimwear                                   515552  ...      515552
# Trousers                                   448022  ...      448022
# Trousers Denim                             184581  ...      184581
# Under-, Nightwear                          494089  ...      494089
# Unknown                                     38662  ...       38662
# Woven/Jersey/Knitted mix Baby                7022  ...        7022
#
#                                section_name  garment_group_no  detail_desc  \
# garment_group_name
# Accessories                          254328            254328       254310
# Blouses                              431929            431929       431900
# Dressed                               72407             72407        72362
# Dresses Ladies                       388742            388742       388722
# Dresses/Skirts girls                   4067              4067         4067
# Jersey Basic                         586898            586898       586890
# Jersey Fancy                         877520            877520       877473
# Knitwear                             226507            226507       226505
# Outdoor                               70172             70172        70172
# Shirts                                33970             33970        33970
# Shoes                                114846            114846       113848
# Shorts                               166679            166679       166670
# Skirts                               113024            113024       113019
# Socks and Tights                      97684             97684        97684
# Special Offers                        24769             24769        24769
# Swimwear                             515552            515552       514560
# Trousers                             448022            448022       447938
# Trousers Denim                       184581            184581       184581
# Under-, Nightwear                    494089            494089       492732
# Unknown                               38662             38662        38662
# Woven/Jersey/Knitted mix Baby          7022              7022         7022
#
#                                    FN  Active  club_member_status  \
# garment_group_name
# Accessories                    117210  115181              254038
# Blouses                        206972  204203              431363
# Dressed                         33675   33238               72306
# Dresses Ladies                 189229  186668              388196
# Dresses/Skirts girls             1996    1966                4060
# Jersey Basic                   256654  252834              585932
# Jersey Fancy                   395462  389857              876399
# Knitwear                       103797  102439              226133
# Outdoor                         32565   32149               70045
# Shirts                          15762   15546               33948
# Shoes                           56769   55850              114665
# Shorts                          72850   71810              166511
# Skirts                          52253   51505              112866
# Socks and Tights                41022   40340               97584
# Special Offers                  12691   12529               24708
# Swimwear                       213851  210220              514793
# Trousers                       204071  201058              447378
# Trousers Denim                  82938   81805              184311
# Under-, Nightwear              209380  206203              493428
# Unknown                         17973   17730               38613
# Woven/Jersey/Knitted mix Baby    3155    3101                6988
#
#                                fashion_news_frequency     age  postal_code
# garment_group_name
# Accessories                                    253477  253312       254328
# Blouses                                        430942  430385       431929
# Dressed                                         72270   72140        72407
# Dresses Ladies                                 387975  387559       388742
# Dresses/Skirts girls                             4057    4050         4067
# Jersey Basic                                   585429  584441       586898
# Jersey Fancy                                   875260  874030       877520
# Knitwear                                       225986  225715       226507
# Outdoor                                         70037   69941        70172
# Shirts                                          33894   33824        33970
# Shoes                                          114648  114498       114846
# Shorts                                         166253  165984       166679
# Skirts                                         112791  112686       113024
# Socks and Tights                                97296   97173        97684
# Special Offers                                  24729   24694        24769
# Swimwear                                       514359  513612       515552
# Trousers                                       447102  446283       448022
# Trousers Denim                                 184216  183942       184581
# Under-, Nightwear                              492667  491898       494089
# Unknown                                         38583   38526        38662
# Woven/Jersey/Knitted mix Baby                    6991    6973         7022
#
# [21 rows x 34 columns]

# %%
LadiesWearFilter=TransactionsAndArticlesAndCustomers['index_group_name'].str.contains('Ladieswear')

# %%
regexPattern=r'\bTrousers\b'

# %%
TrousersFilter=TransactionsAndArticlesAndCustomers['garment_group_name'].str.contains(regexPattern, regex=True)

# %%
TransactionsAndArticlesAndCustomers[LadiesWearFilter & TrousersFilter]
# Out:
#                 t_dat                                        customer_id  \
# t_dat
# 2020-06-01 2020-06-01  000b31552d3785c79833262bbeefa484cbc43d7b612b3c...
# 2020-06-01 2020-06-01  00357392d470d99fd23483a8bee556346b687cc357f237...
# 2020-06-01 2020-06-01  00357392d470d99fd23483a8bee556346b687cc357f237...
# 2020-06-01 2020-06-01  003ecc4871f0f5f1722c36e00e345d76204096c524b68a...
# 2020-06-01 2020-06-01  0040e2fc2d1e7931a38355aca56b2c62b87e65051b7287...
# ...               ...                                                ...
# 2020-09-22 2020-09-22  fe99a0069d6b3c64c2707d0ce53b9311540917471d82df...
# 2020-09-22 2020-09-22  febbccd6dd7885f2501bb56c47af50b122e9f3ab9a7472...
# 2020-09-22 2020-09-22  fee9fcf27b395c43053f36697af5766fdaaf428b13f8ef...
# 2020-09-22 2020-09-22  ffb72741f3bc3d98855703b55d34e05bc7893a5d6a99a3...
# 2020-09-22 2020-09-22  ffb72741f3bc3d98855703b55d34e05bc7893a5d6a99a3...
#
#             article_id     price  sales_channel_id  product_code  \
# t_dat
# 2020-06-01   777016001  0.030492                 1        777016
# 2020-06-01   880867004  0.050831                 2        880867
# 2020-06-01   871974001  0.059305                 2        871974
# 2020-06-01   757347001  0.050831                 2        757347
# 2020-06-01   862325002  0.036000                 2        862325
# ...                ...       ...               ...           ...
# 2020-09-22   562245018  0.023712                 2        562245
# 2020-09-22   836540005  0.064390                 2        836540
# 2020-09-22   886241001  0.027102                 1        886241
# 2020-09-22   751471041  0.033881                 2        751471
# 2020-09-22   751471038  0.033881                 2        751471
#
#                                prod_name  product_type_no  product_type_name  \
# t_dat
# 2020-06-01                   Cisco skirt              275              Skirt
# 2020-06-01              Juniper playsuit              272           Trousers
# 2020-06-01  Tarly indigo tencel playsuit              272           Trousers
# 2020-06-01       LOGG Iris linen jogger'              272           Trousers
# 2020-06-01                      Felix HW              272           Trousers
# ...                                  ...              ...                ...
# 2020-09-22                Luna skinny RW              272           Trousers
# 2020-09-22             Push up ankle (D)              272           Trousers
# 2020-09-22              Bahamas jumpsuit              267  Jumpsuit/Playsuit
# 2020-09-22           Pluto RW slacks (1)              272           Trousers
# 2020-09-22           Pluto RW slacks (1)              272           Trousers
#
#             product_group_name  ...                section_name  \
# t_dat                           ...
# 2020-06-01  Garment Lower body  ...                Womens Trend
# 2020-06-01  Garment Lower body  ...               Womens Casual
# 2020-06-01  Garment Lower body  ...               Womens Casual
# 2020-06-01  Garment Lower body  ...                        H&M+
# 2020-06-01  Garment Lower body  ...  Womens Everyday Collection
# ...                        ...  ...                         ...
# 2020-09-22  Garment Lower body  ...  Womens Everyday Collection
# 2020-09-22  Garment Lower body  ...                        Mama
# 2020-09-22   Garment Full body  ...  Womens Everyday Collection
# 2020-09-22  Garment Lower body  ...  Womens Everyday Collection
# 2020-09-22  Garment Lower body  ...  Womens Everyday Collection
#
#            garment_group_no  garment_group_name  \
# t_dat
# 2020-06-01             1009            Trousers
# 2020-06-01             1009            Trousers
# 2020-06-01             1009            Trousers
# 2020-06-01             1009            Trousers
# 2020-06-01             1009            Trousers
# ...                     ...                 ...
# 2020-09-22             1009            Trousers
# 2020-09-22             1009            Trousers
# 2020-09-22             1009            Trousers
# 2020-09-22             1009            Trousers
# 2020-09-22             1009            Trousers
#
#                                                   detail_desc   FN Active  \
# t_dat
# 2020-06-01  Calf-length skirt in softly draping, patterned...  1.0    1.0
# 2020-06-01  Sleeveless playsuit in a viscose and linen wea...  NaN    NaN
# 2020-06-01  Playsuit in soft, washed Tencel™ lyocell denim...  NaN    NaN
# 2020-06-01  Trousers in airy linen. Relaxed fit with a reg...  1.0    1.0
# 2020-06-01  Ankle-length trousers in twill made from a vis...  NaN    NaN
# ...                                                       ...  ...    ...
# 2020-09-22  5-pocket jeans in washed, superstretch denim w...  1.0    1.0
# 2020-09-22  Ankle-length jeggings in washed, stretch denim...  1.0    1.0
# 2020-09-22  Jumpsuit in woven fabric with wide, flounce-tr...  1.0    1.0
# 2020-09-22  Ankle-length cigarette trousers in a stretch w...  NaN    NaN
# 2020-09-22  Ankle-length cigarette trousers in a stretch w...  NaN    NaN
#
#             club_member_status fashion_news_frequency   age  \
# t_dat
# 2020-06-01              ACTIVE              Regularly  59.0
# 2020-06-01              ACTIVE                   NONE  32.0
# 2020-06-01              ACTIVE                   NONE  32.0
# 2020-06-01              ACTIVE              Regularly  34.0
# 2020-06-01              ACTIVE                   NONE  39.0
# ...                        ...                    ...   ...
# 2020-09-22              ACTIVE              Regularly  48.0
# 2020-09-22              ACTIVE              Regularly  33.0
# 2020-09-22              ACTIVE              Regularly  28.0
# 2020-09-22              ACTIVE                   NONE  26.0
# 2020-09-22              ACTIVE                   NONE  26.0
#
#                                                   postal_code
# t_dat
# 2020-06-01  2c29ae653a9282cce4151bd87643c907644e09541abc28...
# 2020-06-01  fb06cbc1bd9e3d9037d586c7f790f99f8c491620be9d03...
# 2020-06-01  fb06cbc1bd9e3d9037d586c7f790f99f8c491620be9d03...
# 2020-06-01  d4539e3081df4f09c0eb92737df51f880f7367821add99...
# 2020-06-01  8d19ecf2057b7199b28648c237af6b048c495118325581...
# ...                                                       ...
# 2020-09-22  3fc97fb9464411bfb0f0739a0c5040d0bc1e94cdc02363...
# 2020-09-22  3c32ab05679c20304e50b754b9d33447e62adb39b7665f...
# 2020-09-22  cd63d5c1451b873e246e0f0bcda632b53244e02120e41c...
# 2020-09-22  97f87a076cd480253739cadad692d95aa2c636c6f5141f...
# 2020-09-22  97f87a076cd480253739cadad692d95aa2c636c6f5141f...
#
# [307634 rows x 35 columns]
